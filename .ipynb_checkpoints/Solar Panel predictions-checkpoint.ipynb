# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import urllib

# %%
train_df['date'] = train_df['date'].apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))

# %%
train_df
# Out:
#            date  solar_produced_per_day  daylight  daylight_avg_temp  \
# 0    2011-10-27                    10.1     604.0              14.70
# 1    2011-10-28                    10.0     600.0              16.00
# 2    2011-10-29                     9.4     597.0              15.30
# 3    2011-10-30                     4.6     593.0              15.10
# 4    2011-10-31                     3.8     589.0              15.00
# ...         ...                     ...       ...                ...
# 3298 2020-11-06                     8.0     567.0               9.50
# 3299 2020-11-07                     8.0     563.0              14.25
# 3300 2020-11-08                     8.0     560.0              15.20
# 3301 2020-11-09                     5.0     556.0              14.45
# 3302 2020-11-10                     3.0     553.0              13.40
#
#       avg_cloudcover  avg_direct_radiation  weather  max_wind_speed  max_temp
# ...

# %%
train_df['date']
# Out:
# 0      2011-10-27
# 1      2011-10-28
# 2      2011-10-29
# 3      2011-10-30
# 4      2011-10-31
#           ...
# 3298   2020-11-06
# 3299   2020-11-07
# 3300   2020-11-08
# 3301   2020-11-09
# 3302   2020-11-10
# Name: date, Length: 3303, dtype: datetime64[ns]

# %%
import matplotlib.pyplot as plt

# %%
# solar_produced_per_day
plt.figure().set_figwidth(17)
plot_year= train_df[(train_df['date'] >= datetime.strptime('2012-01-01','%Y-%m-%d')) & (train_df['date'] <= datetime.strptime('2013-12-31','%Y-%m-%d')) ]
plt.plot(plot_year['date'].to_numpy(),plot_year['solar_produced_per_day'].to_numpy())
plt.show()

# %%
#daylight
plt.figure().set_figwidth(17)
plt.plot(plot_year['date'].to_numpy(),plot_year['daylight'].to_numpy())
plt.show()

# %%
plt.figure().set_figwidth(17)
plt.plot(plot_year['date'].to_numpy(),plot_year['daylight_avg_temp'].to_numpy())
plt.show()

# %%
plt.figure().set_figwidth(17)
plt.scatter(plot_year['date'].to_numpy(),plot_year['weather'].to_numpy())
plt.show()

# %%
plt.figure().set_figwidth(17)
plt.plot(plot_year['date'].to_numpy(),plot_year['max_wind_speed'].to_numpy())
plt.show()

# %%
plt.figure().set_figwidth(17)
plt.plot(plot_year['date'].to_numpy(),plot_year['max_temp'].to_numpy())
plt.show()

# %%
train_df['date'] = train_df['date'].apply(lambda x: int(x.strftime('%m').replace('0', '')))

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, MultiTaskLasso, Lasso, ElasticNet, SGDRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, VotingRegressor, StackingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
import math
# train_df['date'] =  train_df['date'].apply(lambda x: int(x.strftime('%m').replace('0', '')))

# %%
X=train_df.drop('solar_produced_per_day', axis=1)
y = train_df['solar_produced_per_day']
X_train,X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state=1,
    train_size=0.8
    )

# %%
X_train
# Out:
#       date  daylight  daylight_avg_temp  avg_cloudcover  avg_direct_radiation  \
# 81       1     509.0               1.80             0.0                  94.0
# 151      3     759.0              13.50             1.0                 305.0
# 761     11     509.0               6.90            91.5                  23.5
# 2474     8     914.0              25.50             7.0                 282.0
# 1392     8     867.0              20.45            19.0                 250.0
# ...    ...       ...                ...             ...                   ...
# 2763     5     955.0              13.80            92.0                  60.5
# 905      4     850.0              12.05            79.0                 111.5
# 1096     1     603.0              15.40            34.0                 126.5
# 235      6    1000.0              17.00            58.0                 139.0
# 1061     9     737.0              15.30            74.5                 112.0
#
# ...

# %%
import random

# %%
# tuning models
smallest_mean_score = -19293939
smallest_std_score = 129391293
smallest_mean_score_C = 0
smallest_std_C = 0 
for i in range(1, 100001,  1):
    k = random.choice([i for i in range(10,1010, 10)])
    m = random.randint(1,6)
    r = random.choice([i for i in range(10,110, 10)])
    w = random.choice([i for i in range(1, 11)])
    z = random.choice([i for i in range(1, 11)])
    model =  xgb.XGBRegressor(n_estimators=100, max_depth=2, learning_rate=0.1)
    score = cross_val_score(model,X,y, cv=10, scoring='neg_root_mean_squared_error')
    print(score.mean(), score.std(), k ,m, r, w,z )
    if smallest_mean_score < score.mean():
        smallest_mean_score = score.mean()
        smallest_mean_score_C= r/1000000
    if smallest_std_score > score.std():
        smallest_std_score = score.std()
        smallest_std_C = r/1000000
# Out:
# -4.364571523897193 0.25168973788295185 290 6 100 5 7
# -4.364571523897193 0.25168973788295185 700 6 20 9 1
# -4.364571523897193 0.25168973788295185 260 4 20 7 9
# -4.364571523897193 0.25168973788295185 480 5 50 2 2
# -4.364571523897193 0.25168973788295185 770 2 60 6 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [134], in <cell line: 6>()
#      11 z = random.choice([i for i in range(1, 11)])
#      12 model =  xgb.XGBRegressor(n_estimators=100, max_depth=2, learning_rate=0.1)
# ---> 13 score = cross_val_score(model,X,y, cv=10, scoring='neg_root_mean_squared_error')
#      14 print(score.mean(), score.std(), k ,m, r, w,z )
#      15 if smallest_mean_score < score.mean():
#
# ...

# %%
#0.2303926017367737 0.39129
# 4.434540361053999 0.2305814033452999
print(smallest_mean_score, smallest_mean_score_C)
print(smallest_std_score,smallest_std_C)
# Out:
# -4.414601200906603 1e-05
# 0.22305377183184652 1e-05

# %%
X_train
s = make_pipeline(StandardScaler(),svm.SVR(kernel='rbf', gamma='scale', C=0.824302))
bgs = BaggingRegressor(s, random_state=1)
rd = make_pipeline(StandardScaler(),Ridge(positive=True, random_state=1))
lr = LinearRegression(positive=True)
rf =make_pipeline(StandardScaler(), RandomForestRegressor(n_estimators=90, max_depth=6, random_state=41))
el = ElasticNet(alpha=0.001225, random_state=1)
xgb_m =  xgb.XGBRegressor(n_estimators=100, max_depth=2, learning_rate=0.1)
estimators = [
    ('svr', s),
    ('rf', rf),
    ('lr', lr),
]
model = make_pipeline(StandardScaler(), VotingRegressor(estimators, weights=[9,6, 6]))
# model = s
# model = make_pipeline(StandardScaler(), StackingRegressor(estimators=estimators, final_estimator=LinearRegression()))
model.fit(X, y)

predictions = model.predict(X_test)
score = cross_val_score(model,X,y, cv=10, scoring='neg_root_mean_squared_error')
# print(math.sqrt(mean_squared_error(y_test, predictions)))
print(score.mean(), score.std())
# Out:
# -4.345661236892196 0.21896999829908587

# %%
print(predictions)
print(y_test)
# Out:
# [23.06029325 15.72667143  2.43049739 13.22276127  4.03098271 18.41977973
#  13.01079906 11.6169625   2.46805326 22.17346357 15.53225622  1.50347084
#  12.98426833 15.516084    2.12410842 15.71888895 13.80447465  6.39450239
#   1.58677254  2.48425252  1.49185976 11.4511251   1.95001395  8.78525483
#  15.90953142  3.51690941 15.72478306  6.80500988 15.77266099  6.5326298
#   5.967189    2.16110801 15.41795056  1.99886323  3.74265818 13.99069677
#  18.61068294 13.08051597 15.38533057 18.19372799  6.54227545 13.84459003
#  18.18542282 17.50573391  3.56873526 15.04436803  4.22665286 12.72013681
#   8.77226345 22.64168233 14.04666402 24.97402235  2.9579487   1.47049716
#   6.80653723 12.48813205 14.05590278  2.76227387  1.83168313 14.52121565
#   1.77162025  2.68018939 12.48773308  1.69363688 15.83565553  4.67384877
#   5.60587215 11.47410782  1.63496926  3.02015046  8.60349623 14.62698016
#  15.26892447  5.51599443 10.592466   11.41192182  4.42864993  4.08287839
# ...

# %%
import xgboost as xgb

# %%
xgb_m = 
score = cross_val_score(xgb_m,X,y, cv=10, scoring='neg_root_mean_squared_error')
print(score.mean(), score.std())
# Out:
# -4.534305440828845 0.28150049185513226
